# %%
import json
import pandas as pd
from typing import List, Dict, Any
import re
import numpy as np

def read_jsonl_file(filename: str) -> List[Dict[str, Any]]:
    """Read a JSONL file and return a list of dictionaries."""
    data = []
    with open(filename, 'r', encoding='utf-8') as file:
        for line_num, line in enumerate(file, 1):
            try:
                line = line.strip()
                if not line:
                    continue
                json_obj = json.loads(line)
                data.append(json_obj)
            except json.JSONDecodeError as e:
                print(f"Error parsing JSON on line {line_num}: {e}")
                continue
    return data

def convert_to_dataframe(data: List[Dict[str, Any]]) -> pd.DataFrame:
    """Convert the JSONL data to a pandas DataFrame."""
    records = []
    
    for game in data:
        record = {
            'target_word': game['metadata']['target_word'],
            'attempts_used': game['metadata']['attempts_used'],
            'solved': game['metadata']['solved'],
            'total_reward': game['metadata']['total_reward'],
            'num_messages': len(game['messages']),
        }
        
        # Extract first guess
        assistant_messages = [msg for msg in game['messages'] if msg['role'] == 'assistant']
        if assistant_messages:
            first_guess = assistant_messages[0]['content']
            match = re.search(r'\\boxed\{(\w+)\}', first_guess)
            record['first_guess'] = match.group(1) if match else 'unknown'
        
        records.append(record)
    
    return pd.DataFrame(records)

# %%
# Read the data and create initial solved_df
print("Reading JSONL file...")
data = read_jsonl_file('wordle_examples.jsonl')
df = convert_to_dataframe(data)
print(f"DataFrame shape: {df.shape}")

# Filter to solved games only
solved_df = df[df['solved'] == True]
print(f"Solved games: {len(solved_df)}")

print("\nSolved games by attempts:")
print(solved_df['attempts_used'].value_counts().sort_index())

print("\nTarget word counts (showing words with >25 games):")
target_counts = solved_df['target_word'].value_counts()
high_count_words = target_counts[target_counts > 25]
for word, count in high_count_words.items():
    print(f"{word} {count}")

print(f"\nTotal unique target words: {solved_df['target_word'].nunique()}")
print(f"Max games per target word: {target_counts.max()}")
print(f"Words with >15 games: {sum(target_counts > 15)}")

# %%
# METHOD 1: Take first 15 rows for each target word (deterministic)
print("=== METHOD 1: First 15 rows per target word ===")
filtered_df_first15 = solved_df.groupby('target_word').head(15).reset_index(drop=True)

print(f"Original solved_df shape: {solved_df.shape}")
print(f"Filtered (first 15 per target) shape: {filtered_df_first15.shape}")
print(f"Reduction: {len(solved_df) - len(filtered_df_first15)} rows removed")

print("\nTarget word counts after filtering (top 10):")
print(filtered_df_first15['target_word'].value_counts().head(10))

print(f"\nMax rows per target word: {filtered_df_first15['target_word'].value_counts().max()}")
print(f"Min rows per target word: {filtered_df_first15['target_word'].value_counts().min()}")

# %%
# METHOD 2: Random sample of up to 15 rows per target word
print("=== METHOD 2: Random 15 rows per target word ===")

# Set random seed for reproducibility
np.random.seed(42)

def sample_max_n(group, n=15):
    if len(group) <= n:
        return group
    else:
        return group.sample(n=n)

filtered_df_random15 = solved_df.groupby('target_word').apply(lambda x: sample_max_n(x, 15)).reset_index(drop=True)

print(f"Original solved_df shape: {solved_df.shape}")
print(f"Filtered (random 15 per target) shape: {filtered_df_random15.shape}")
print(f"Reduction: {len(solved_df) - len(filtered_df_random15)} rows removed")

print("\nTarget word counts after random filtering (top 10):")
print(filtered_df_random15['target_word'].value_counts().head(10))

print(f"\nMax rows per target word: {filtered_df_random15['target_word'].value_counts().max()}")

# Compare attempt distributions
print("\n--- Attempt Distribution Comparison ---")
print("Original:")
print(solved_df['attempts_used'].value_counts().sort_index())
print("\nFiltered (first 15):")
print(filtered_df_first15['attempts_used'].value_counts().sort_index())
print("\nFiltered (random 15):")
print(filtered_df_random15['attempts_used'].value_counts().sort_index())

# %%
# FINAL STEP: Choose your preferred filtering method
print("=== CHOOSE YOUR FILTERING METHOD ===")

# Option 1: First 15 (deterministic, preserves original order)
solved_df = filtered_df_first15.copy()

# Option 2: Random 15 (random sampling - uncomment to use)
# solved_df = filtered_df_random15.copy()

print(f"Final solved_df shape: {solved_df.shape}")
print(f"Max rows per target word: {solved_df['target_word'].value_counts().max()}")
print(f"Min rows per target word: {solved_df['target_word'].value_counts().min()}")
print(f"Number of unique target words: {solved_df['target_word'].nunique()}")

print(f"\nDataFrame successfully filtered to max 15 rows per target word!")
print(f"Reduced from {len(data)} total games to {len(solved_df)} solved games with balanced target word distribution.")

# %%
import json
import pandas as pd
from typing import List, Dict, Any
import random

def read_jsonl_file(filename: str) -> List[Dict[str, Any]]:
    """
    Read a JSONL file and return a list of dictionaries.
    Each line in the file should be a valid JSON object.
    """
    data = []
    with open(filename, 'r', encoding='utf-8') as file:
        for line_num, line in enumerate(file, 1):
            try:
                # Strip whitespace and skip empty lines
                line = line.strip()
                if not line:
                    continue
                
                # Parse JSON
                json_obj = json.loads(line)
                data.append(json_obj)
                
            except json.JSONDecodeError as e:
                print(f"Error parsing JSON on line {line_num}: {e}")
                continue
    
    return data

def analyze_wordle_data(data: List[Dict[str, Any]]) -> None:
    """
    Analyze the Wordle game data and print some basic statistics.
    """
    print(f"Total games: {len(data)}")
    
    # Extract metadata
    solved_games = [game for game in data if game['metadata']['solved']]
    failed_games = [game for game in data if not game['metadata']['solved']]
    
    print(f"Games solved: {len(solved_games)}")
    print(f"Games failed: {len(failed_games)}")
    print(f"Success rate: {len(solved_games) / len(data) * 100:.1f}%")
    
    if solved_games:
        avg_attempts = sum(game['metadata']['attempts_used'] for game in solved_games) / len(solved_games)
        print(f"Average attempts for solved games: {avg_attempts:.2f}")
    
    # Show some target words
    target_words = [game['metadata']['target_word'] for game in data[:10]]
    print(f"\nFirst 10 target words: {target_words}")

def sample_max_n_games(games: List[Dict[str, Any]], n: int = 10) -> List[Dict[str, Any]]:
    """
    Sample at most n games from a list, preserving full structure.
    """
    if len(games) <= n:
        return games
    else:
        return random.sample(games, n)

def filter_and_save_jsonl(input_filename: str, output_filename: str, max_per_word: int = 10) -> None:
    """
    Filter JSONL file to keep only solved games, max N per target word, preserving full structure.
    """
    # Read all data
    print("Reading JSONL file...")
    data = read_jsonl_file(input_filename)
    
    # Filter to only solved games
    solved_games = [game for game in data if game['metadata']['solved']]
    print(f"Found {len(solved_games)} solved games out of {len(data)} total games")
    
    # Group by target word
    games_by_target = {}
    for game in solved_games:
        target_word = game['metadata']['target_word']
        if target_word not in games_by_target:
            games_by_target[target_word] = []
        games_by_target[target_word].append(game)
    
    print(f"Found {len(games_by_target)} unique target words")
    
    # Sample max N games per target word
    filtered_games = []
    for target_word, games in games_by_target.items():
        sampled_games = sample_max_n_games(games, max_per_word)
        filtered_games.extend(sampled_games)
        print(f"Target '{target_word}': {len(games)} -> {len(sampled_games)} games")
    
    print(f"\nTotal filtered games: {len(filtered_games)}")
    
    # Save to new JSONL file
    with open(output_filename, 'w', encoding='utf-8') as f:
        for game in filtered_games:
            f.write(json.dumps(game, ensure_ascii=False) + '\n')
    
    print(f"Saved filtered data to {output_filename}")
    
    # Print summary statistics
    target_word_counts = {}
    for game in filtered_games:
        target_word = game['metadata']['target_word']
        target_word_counts[target_word] = target_word_counts.get(target_word, 0) + 1
    
    print(f"\nFinal distribution:")
    for word, count in sorted(target_word_counts.items()):
        print(f"  {word}: {count}")

# Example usage
if __name__ == "__main__":
    # Set random seed for reproducible sampling
    random.seed(42)
    
    # Filter and save
    filter_and_save_jsonl('wordle_examples.jsonl', 'wordle_finetune.jsonl', max_per_word=10)
# Out:
# Reading JSONL file...
# Found 8424 solved games out of 8424 total games
# Found 503 unique target words
# Target 'refer': 23 -> 10 games
# Target 'lower': 10 -> 10 games
# Target 'shine': 18 -> 10 games
# Target 'virus': 16 -> 10 games
# Target 'blast': 21 -> 10 games
# Target 'storm': 14 -> 10 games
# Target 'taste': 25 -> 10 games
# Target 'dream': 23 -> 10 games
# Target 'trunk': 18 -> 10 games
# Target 'chose': 16 -> 10 games
# Target 'brief': 21 -> 10 games
# Target 'mixed': 21 -> 10 games
# Target 'focus': 16 -> 10 games
# Target 'lunch': 15 -> 10 games
# Target 'spare': 22 -> 10 games
# Target 'peter': 19 -> 10 games
# Target 'legal': 25 -> 10 games
# Target 'draft': 16 -> 10 games
# Target 'array': 12 -> 10 games
# Target 'dying': 25 -> 10 games
# Target 'globe': 21 -> 10 games
# Target 'power': 24 -> 10 games
# Target 'plant': 23 -> 10 games
# Target 'earth': 16 -> 10 games
# Target 'lying': 22 -> 10 games
# Target 'train': 18 -> 10 games
# Target 'human': 14 -> 10 games
# Target 'smith': 21 -> 10 games
# Target 'steam': 24 -> 10 games
# Target 'aware': 21 -> 10 games
# Target 'novel': 17 -> 10 games
# Target 'union': 17 -> 10 games
# Target 'sides': 20 -> 10 games
# Target 'could': 18 -> 10 games
# Target 'stick': 17 -> 10 games
# Target 'maker': 13 -> 10 games
# Target 'smoke': 15 -> 10 games
# Target 'route': 12 -> 10 games
# Target 'plate': 15 -> 10 games
# Target 'grand': 19 -> 10 games
# Target 'chart': 17 -> 10 games
# Target 'climb': 16 -> 10 games
# Target 'album': 16 -> 10 games
# Target 'upper': 18 -> 10 games
# Target 'cloud': 17 -> 10 games
# Target 'horse': 22 -> 10 games
# Target 'smart': 19 -> 10 games
# Target 'truly': 12 -> 10 games
# Target 'phase': 17 -> 10 games
# Target 'about': 18 -> 10 games
# Target 'pitch': 21 -> 10 games
# Target 'sharp': 16 -> 10 games
# Target 'sixth': 18 -> 10 games
# Target 'roman': 19 -> 10 games
# Target 'found': 18 -> 10 games
# Target 'dozen': 18 -> 10 games
# Target 'mouse': 16 -> 10 games
# Target 'basic': 12 -> 10 games
# Target 'doubt': 15 -> 10 games
# Target 'large': 20 -> 10 games
# Target 'since': 19 -> 10 games
# Target 'treat': 20 -> 10 games
# Target 'water': 20 -> 10 games
# Target 'green': 21 -> 10 games
# Target 'sense': 13 -> 10 games
# Target 'until': 17 -> 10 games
# Target 'agent': 23 -> 10 games
# Target 'might': 19 -> 10 games
# Target 'terry': 24 -> 10 games
# Target 'wrong': 16 -> 10 games
# Target 'chair': 15 -> 10 games
# Target 'queen': 11 -> 10 games
# Target 'vocal': 13 -> 10 games
# Target 'relax': 22 -> 10 games
# Target 'thank': 24 -> 10 games
# Target 'guard': 13 -> 10 games
# Target 'taken': 17 -> 10 games
# Target 'chain': 19 -> 10 games
# Target 'super': 19 -> 10 games
# Target 'think': 24 -> 10 games
# Target 'threw': 15 -> 10 games
# Target 'acute': 17 -> 10 games
# Target 'ratio': 18 -> 10 games
# Target 'brown': 24 -> 10 games
# Target 'alike': 17 -> 10 games
# Target 'range': 11 -> 10 games
# Target 'meant': 25 -> 10 games
# Target 'count': 8 -> 8 games
# Target 'texas': 22 -> 10 games
# Target 'crash': 17 -> 10 games
# Target 'prime': 17 -> 10 games
# Target 'delay': 24 -> 10 games
# Target 'chase': 19 -> 10 games
# Target 'fault': 18 -> 10 games
# Target 'fixed': 25 -> 10 games
# Target 'split': 20 -> 10 games
# Target 'adopt': 13 -> 10 games
# Target 'false': 15 -> 10 games
# Target 'error': 14 -> 10 games
# Target 'often': 10 -> 10 games
# Target 'youth': 19 -> 10 games
# Target 'needs': 23 -> 10 games
# Target 'house': 22 -> 10 games
# Target 'proud': 11 -> 10 games
# Target 'arena': 11 -> 10 games
# Target 'baker': 22 -> 10 games
# Target 'lewis': 23 -> 10 games
# Target 'group': 13 -> 10 games
# Target 'moral': 15 -> 10 games
# Target 'sweet': 18 -> 10 games
# Target 'piece': 12 -> 10 games
# Target 'crowd': 20 -> 10 games
# Target 'royal': 20 -> 10 games
# Target 'anger': 14 -> 10 games
# Target 'spoke': 17 -> 10 games
# Target 'share': 23 -> 10 games
# Target 'broke': 19 -> 10 games
# Target 'below': 22 -> 10 games
# Target 'boost': 20 -> 10 games
# Target 'fifty': 22 -> 10 games
# Target 'begin': 16 -> 10 games
# Target 'light': 14 -> 10 games
# Target 'alive': 18 -> 10 games
# Target 'model': 19 -> 10 games
# Target 'proof': 21 -> 10 games
# Target 'unity': 19 -> 10 games
# Target 'alien': 10 -> 10 games
# Target 'chaos': 18 -> 10 games
# Target 'write': 22 -> 10 games
# Target 'story': 17 -> 10 games
# Target 'magic': 24 -> 10 games
# Target 'swing': 18 -> 10 games
# Target 'asset': 6 -> 6 games
# Target 'taxes': 12 -> 10 games
# Target 'after': 17 -> 10 games
# Target 'guess': 29 -> 10 games
# Target 'clock': 18 -> 10 games
# Target 'pride': 19 -> 10 games
# Target 'place': 19 -> 10 games
# Target 'small': 24 -> 10 games
# Target 'broad': 13 -> 10 games
# Target 'buyer': 15 -> 10 games
# Target 'mount': 22 -> 10 games
# Target 'truck': 19 -> 10 games
# Target 'index': 24 -> 10 games
# Target 'actor': 11 -> 10 games
# Target 'usage': 11 -> 10 games
# Target 'metal': 20 -> 10 games
# Target 'study': 18 -> 10 games
# Target 'trust': 15 -> 10 games
# Target 'apple': 23 -> 10 games
# Target 'value': 19 -> 10 games
# Target 'bread': 19 -> 10 games
# Target 'trend': 12 -> 10 games
# Target 'paint': 21 -> 10 games
# Target 'stuck': 11 -> 10 games
# Target 'forty': 24 -> 10 games
# Target 'tiger': 21 -> 10 games
# Target 'truth': 22 -> 10 games
# Target 'quite': 13 -> 10 games
# Target 'match': 26 -> 10 games
# Target 'stock': 12 -> 10 games
# Target 'voice': 19 -> 10 games
# Target 'enemy': 19 -> 10 games
# Target 'three': 13 -> 10 games
# Target 'print': 15 -> 10 games
# Target 'blind': 14 -> 10 games
# Target 'young': 21 -> 10 games
# Target 'sugar': 17 -> 10 games
# Target 'jimmy': 8 -> 8 games
# Target 'leave': 19 -> 10 games
# Target 'blood': 17 -> 10 games
# Target 'alarm': 11 -> 10 games
# Target 'scale': 16 -> 10 games
# Target 'align': 18 -> 10 games
# Target 'going': 12 -> 10 games
# Target 'drive': 16 -> 10 games
# Target 'pound': 22 -> 10 games
# Target 'store': 23 -> 10 games
# Target 'clear': 20 -> 10 games
# Target 'cause': 14 -> 10 games
# Target 'allow': 10 -> 10 games
# Target 'cream': 19 -> 10 games
# Target 'ahead': 11 -> 10 games
# Target 'class': 17 -> 10 games
# Target 'night': 16 -> 10 games
# Target 'force': 11 -> 10 games
# Target 'tight': 15 -> 10 games
# Target 'start': 19 -> 10 games
# Target 'laser': 8 -> 8 games
# Target 'panel': 20 -> 10 games
# Target 'issue': 10 -> 10 games
# Target 'trick': 21 -> 10 games
# Target 'above': 14 -> 10 games
# Target 'front': 13 -> 10 games
# Target 'wheel': 17 -> 10 games
# Target 'award': 14 -> 10 games
# Target 'thing': 26 -> 10 games
# Target 'river': 23 -> 10 games
# Target 'learn': 17 -> 10 games
# Target 'moved': 25 -> 10 games
# Target 'noted': 23 -> 10 games
# Target 'world': 16 -> 10 games
# Target 'empty': 21 -> 10 games
# Target 'silly': 12 -> 10 games
# Target 'slide': 16 -> 10 games
# Target 'heart': 21 -> 10 games
# Target 'along': 15 -> 10 games
# Target 'suite': 13 -> 10 games
# Target 'while': 10 -> 10 games
# Target 'board': 12 -> 10 games
# Target 'blame': 19 -> 10 games
# Target 'rural': 17 -> 10 games
# Target 'least': 13 -> 10 games
# Target 'tried': 9 -> 9 games
# Target 'shoot': 18 -> 10 games
# Target 'grown': 11 -> 10 games
# Target 'drank': 21 -> 10 games
# Target 'crude': 13 -> 10 games
# Target 'mayor': 24 -> 10 games
# Target 'flash': 21 -> 10 games
# Target 'clean': 16 -> 10 games
# Target 'drama': 21 -> 10 games
# Target 'undue': 13 -> 10 games
# Target 'swiss': 11 -> 10 games
# Target 'women': 21 -> 10 games
# Target 'sleep': 21 -> 10 games
# Target 'rough': 20 -> 10 games
# Target 'strip': 17 -> 10 games
# Target 'point': 16 -> 10 games
# Target 'blank': 24 -> 10 games
# Target 'money': 14 -> 10 games
# Target 'known': 14 -> 10 games
# Target 'cover': 17 -> 10 games
# Target 'arise': 13 -> 10 games
# Target 'sized': 14 -> 10 games
# Target 'sixty': 17 -> 10 games
# Target 'style': 14 -> 10 games
# Target 'teach': 21 -> 10 games
# Target 'shape': 18 -> 10 games
# Target 'brain': 18 -> 10 games
# Target 'white': 10 -> 10 games
# Target 'shown': 20 -> 10 games
# Target 'drove': 21 -> 10 games
# Target 'third': 20 -> 10 games
# Target 'eight': 14 -> 10 games
# Target 'harry': 24 -> 10 games
# Target 'began': 13 -> 10 games
# Target 'tribe': 14 -> 10 games
# Target 'video': 9 -> 9 games
# Target 'fleet': 17 -> 10 games
# Target 'sport': 21 -> 10 games
# Target 'month': 12 -> 10 games
# Target 'depth': 10 -> 10 games
# Target 'faith': 22 -> 10 games
# Target 'cheap': 19 -> 10 games
# Target 'theft': 28 -> 10 games
# Target 'worry': 23 -> 10 games
# Target 'claim': 19 -> 10 games
# Target 'would': 21 -> 10 games
# Target 'where': 25 -> 10 games
# Target 'every': 19 -> 10 games
# Target 'table': 15 -> 10 games
# Target 'lives': 20 -> 10 games
# Target 'bench': 12 -> 10 games
# Target 'motor': 14 -> 10 games
# Target 'henry': 19 -> 10 games
# Target 'worst': 7 -> 7 games
# Target 'under': 13 -> 10 games
# Target 'scene': 14 -> 10 games
# Target 'break': 15 -> 10 games
# Target 'prize': 24 -> 10 games
# Target 'these': 23 -> 10 games
# Target 'layer': 17 -> 10 games
# Target 'doing': 17 -> 10 games
# Target 'photo': 13 -> 10 games
# Target 'sheet': 23 -> 10 games
# Target 'shall': 15 -> 10 games
# Target 'argue': 12 -> 10 games
# Target 'later': 14 -> 10 games
# Target 'fresh': 15 -> 10 games
# Target 'close': 11 -> 10 games
# Target 'bases': 10 -> 10 games
# Target 'grave': 21 -> 10 games
# Target 'pilot': 16 -> 10 games
# Target 'alone': 15 -> 10 games
# Target 'final': 20 -> 10 games
# Target 'frame': 19 -> 10 games
# Target 'arrow': 7 -> 7 games
# Target 'funny': 14 -> 10 games
# Target 'stage': 16 -> 10 games
# Target 'frank': 19 -> 10 games
# Target 'adult': 18 -> 10 games
# Target 'stood': 30 -> 10 games
# Target 'ready': 20 -> 10 games
# Target 'radio': 15 -> 10 games
# Target 'steer': 9 -> 9 games
# Target 'being': 21 -> 10 games
# Target 'quick': 21 -> 10 games
# Target 'block': 19 -> 10 games
# Target 'inner': 19 -> 10 games
# Target 'exact': 18 -> 10 games
# Target 'fraud': 15 -> 10 games
# Target 'ocean': 9 -> 9 games
# Target 'awake': 20 -> 10 games
# Target 'thumb': 20 -> 10 games
# Target 'phone': 13 -> 10 games
# Target 'alter': 14 -> 10 games
# Target 'newly': 25 -> 10 games
# Target 'cable': 23 -> 10 games
# Target 'cross': 17 -> 10 games
# Target 'thick': 14 -> 10 games
# Target 'event': 24 -> 10 games
# Target 'their': 25 -> 10 games
# Target 'given': 12 -> 10 games
# Target 'angle': 12 -> 10 games
# Target 'worth': 17 -> 10 games
# Target 'reply': 22 -> 10 games
# Target 'watch': 18 -> 10 games
# Target 'exist': 17 -> 10 games
# Target 'judge': 12 -> 10 games
# Target 'peace': 21 -> 10 games
# Target 'heavy': 13 -> 10 games
# Target 'crazy': 22 -> 10 games
# Target 'whose': 15 -> 10 games
# Target 'seven': 12 -> 10 games
# Target 'brand': 7 -> 7 games
# Target 'laugh': 20 -> 10 games
# Target 'party': 17 -> 10 games
# Target 'press': 26 -> 10 games
# Target 'birth': 13 -> 10 games
# Target 'score': 12 -> 10 games
# Target 'steel': 22 -> 10 games
# Target 'swift': 21 -> 10 games
# Target 'bring': 12 -> 10 games
# Target 'wrote': 20 -> 10 games
# Target 'reach': 20 -> 10 games
# Target 'staff': 24 -> 10 games
# Target 'plane': 17 -> 10 games
# Target 'extra': 21 -> 10 games
# Target 'maria': 12 -> 10 games
# Target 'rival': 16 -> 10 games
# Target 'enjoy': 24 -> 10 games
# Target 'urban': 23 -> 10 games
# Target 'shelf': 14 -> 10 games
# Target 'repay': 18 -> 10 games
# Target 'early': 21 -> 10 games
# Target 'fully': 13 -> 10 games
# Target 'first': 14 -> 10 games
# Target 'trial': 18 -> 10 games
# Target 'ideal': 10 -> 10 games
# Target 'happy': 17 -> 10 games
# Target 'apply': 25 -> 10 games
# Target 'field': 12 -> 10 games
# Target 'major': 22 -> 10 games
# Target 'smile': 15 -> 10 games
# Target 'avoid': 10 -> 10 games
# Target 'elite': 22 -> 10 games
# Target 'north': 17 -> 10 games
# Target 'tries': 15 -> 10 games
# Target 'rapid': 17 -> 10 games
# Target 'china': 11 -> 10 games
# Target 'those': 17 -> 10 games
# Target 'spent': 15 -> 10 games
# Target 'build': 6 -> 6 games
# Target 'maybe': 22 -> 10 games
# Target 'brave': 22 -> 10 games
# Target 'eager': 17 -> 10 games
# Target 'twice': 27 -> 10 games
# Target 'grade': 25 -> 10 games
# Target 'limit': 14 -> 10 games
# Target 'stand': 19 -> 10 games
# Target 'short': 19 -> 10 games
# Target 'grass': 19 -> 10 games
# Target 'built': 13 -> 10 games
# Target 'fiber': 19 -> 10 games
# Target 'lucky': 12 -> 10 games
# Target 'media': 10 -> 10 games
# Target 'curve': 11 -> 10 games
# Target 'entry': 22 -> 10 games
# Target 'shock': 14 -> 10 games
# Target 'angry': 19 -> 10 games
# Target 'drink': 16 -> 10 games
# Target 'shell': 20 -> 10 games
# Target 'woman': 14 -> 10 games
# Target 'dress': 8 -> 8 games
# Target 'prior': 12 -> 10 games
# Target 'fight': 9 -> 9 games
# Target 'admit': 12 -> 10 games
# Target 'craft': 13 -> 10 games
# Target 'beach': 16 -> 10 games
# Target 'whole': 10 -> 10 games
# Target 'stuff': 16 -> 10 games
# Target 'agree': 12 -> 10 games
# Target 'spend': 22 -> 10 games
# Target 'shirt': 20 -> 10 games
# Target 'never': 22 -> 10 games
# Target 'rigid': 14 -> 10 games
# Target 'great': 22 -> 10 games
# Target 'badly': 13 -> 10 games
# Target 'input': 16 -> 10 games
# Target 'apart': 19 -> 10 games
# Target 'minus': 13 -> 10 games
# Target 'valid': 16 -> 10 games
# Target 'civil': 21 -> 10 games
# Target 'plain': 27 -> 10 games
# Target 'forum': 13 -> 10 games
# Target 'loose': 9 -> 9 games
# Target 'calif': 17 -> 10 games
# Target 'visit': 20 -> 10 games
# Target 'stone': 18 -> 10 games
# Target 'fruit': 20 -> 10 games
# Target 'waste': 15 -> 10 games
# Target 'chest': 13 -> 10 games
# Target 'click': 16 -> 10 games
# Target 'black': 12 -> 10 games
# Target 'music': 5 -> 5 games
# Target 'serve': 15 -> 10 games
# Target 'fluid': 10 -> 10 games
# Target 'skill': 15 -> 10 games
# Target 'rebel': 22 -> 10 games
# Target 'guide': 9 -> 9 games
# Target 'floor': 10 -> 10 games
# Target 'child': 12 -> 10 games
# Target 'steep': 21 -> 10 games
# Target 'raise': 11 -> 10 games
# Target 'check': 10 -> 10 games
# Target 'space': 13 -> 10 games
# Target 'state': 21 -> 10 games
# Target 'crown': 14 -> 10 games
# Target 'which': 25 -> 10 games
# Target 'ought': 9 -> 9 games
# Target 'bound': 9 -> 9 games
# Target 'again': 9 -> 9 games
# Target 'carry': 18 -> 10 games
# Target 'breed': 11 -> 10 games
# Target 'realm': 18 -> 10 games
# Target 'equal': 18 -> 10 games
# Target 'trade': 16 -> 10 games
# Target 'noise': 24 -> 10 games
# Target 'forth': 21 -> 10 games
# Target 'catch': 15 -> 10 games
# Target 'gross': 17 -> 10 games
# Target 'abuse': 12 -> 10 games
# Target 'chief': 12 -> 10 games
# Target 'vital': 8 -> 8 games
# Target 'upset': 10 -> 10 games
# Target 'level': 15 -> 10 games
# Target 'paper': 18 -> 10 games
# Target 'speak': 10 -> 10 games
# Target 'speed': 20 -> 10 games
# Target 'worse': 12 -> 10 games
# Target 'charm': 23 -> 10 games
# Target 'fifth': 24 -> 10 games
# Target 'march': 21 -> 10 games
# Target 'court': 21 -> 10 games
# Target 'tower': 15 -> 10 games
# Target 'lease': 16 -> 10 games
# Target 'right': 10 -> 10 games
# Target 'quiet': 9 -> 9 games
# Target 'billy': 16 -> 10 games
# Target 'track': 13 -> 10 games
# Target 'piano': 9 -> 9 games
# Target 'drill': 21 -> 10 games
# Target 'other': 10 -> 10 games
# Target 'nurse': 7 -> 7 games
# Target 'shift': 10 -> 10 games
# Target 'crime': 8 -> 8 games
# Target 'aside': 4 -> 4 games
# Target 'guest': 15 -> 10 games
# Target 'jones': 9 -> 9 games
# Target 'coach': 23 -> 10 games
# Target 'stake': 13 -> 10 games
# Target 'coast': 16 -> 10 games
# Target 'order': 19 -> 10 games
# Target 'offer': 20 -> 10 games
# Target 'brass': 15 -> 10 games
# Target 'still': 14 -> 10 games
# Target 'grace': 19 -> 10 games
# Target 'round': 14 -> 10 games
# Target 'prove': 16 -> 10 games
# Target 'usual': 6 -> 6 games
# Target 'hotel': 16 -> 10 games
# Target 'label': 15 -> 10 games
# Target 'joint': 21 -> 10 games
# Target 'mouth': 14 -> 10 games
# Target 'glass': 15 -> 10 games
# Target 'enter': 17 -> 10 games
# Target 'sight': 10 -> 10 games
# Target 'booth': 14 -> 10 games
# Target 'local': 13 -> 10 games
# Target 'japan': 9 -> 9 games
# Target 'giant': 16 -> 10 games
# Target 'grant': 16 -> 10 games
# Target 'scope': 21 -> 10 games
# Target 'throw': 10 -> 10 games
# Target 'among': 6 -> 6 games
# Target 'movie': 13 -> 10 games
# Target 'links': 9 -> 9 games
# Target 'alert': 20 -> 10 games
# Target 'price': 16 -> 10 games
# Target 'minor': 11 -> 10 games
# Target 'image': 14 -> 10 games
#
# Total filtered games: 4964
# Saved filtered data to wordle_finetune.jsonl
#
# Final distribution:
#   about: 10
#   above: 10
#   abuse: 10
#   actor: 10
#   acute: 10
#   admit: 10
#   adopt: 10
#   adult: 10
#   after: 10
#   again: 9
#   agent: 10
#   agree: 10
#   ahead: 10
#   alarm: 10
#   album: 10
#   alert: 10
#   alien: 10
#   align: 10
#   alike: 10
#   alive: 10
#   allow: 10
#   alone: 10
#   along: 10
#   alter: 10
#   among: 6
#   anger: 10
#   angle: 10
#   angry: 10
#   apart: 10
#   apple: 10
#   apply: 10
#   arena: 10
#   argue: 10
#   arise: 10
#   array: 10
#   arrow: 7
#   aside: 4
#   asset: 6
#   avoid: 10
#   awake: 10
#   award: 10
#   aware: 10
#   badly: 10
#   baker: 10
#   bases: 10
#   basic: 10
#   beach: 10
#   began: 10
#   begin: 10
#   being: 10
#   below: 10
#   bench: 10
#   billy: 10
#   birth: 10
#   black: 10
#   blame: 10
#   blank: 10
#   blast: 10
#   blind: 10
#   block: 10
#   blood: 10
#   board: 10
#   boost: 10
#   booth: 10
#   bound: 9
#   brain: 10
#   brand: 7
#   brass: 10
#   brave: 10
#   bread: 10
#   break: 10
#   breed: 10
#   brief: 10
#   bring: 10
#   broad: 10
#   broke: 10
#   brown: 10
#   build: 6
#   built: 10
#   buyer: 10
#   cable: 10
#   calif: 10
#   carry: 10
#   catch: 10
#   cause: 10
#   chain: 10
#   chair: 10
#   chaos: 10
#   charm: 10
#   chart: 10
#   chase: 10
#   cheap: 10
#   check: 10
#   chest: 10
#   chief: 10
#   child: 10
#   china: 10
#   chose: 10
#   civil: 10
#   claim: 10
#   class: 10
#   clean: 10
#   clear: 10
#   click: 10
#   climb: 10
#   clock: 10
#   close: 10
#   cloud: 10
#   coach: 10
#   coast: 10
#   could: 10
#   count: 8
#   court: 10
#   cover: 10
#   craft: 10
#   crash: 10
#   crazy: 10
#   cream: 10
#   crime: 8
#   cross: 10
#   crowd: 10
#   crown: 10
#   crude: 10
#   curve: 10
#   delay: 10
#   depth: 10
#   doing: 10
#   doubt: 10
#   dozen: 10
#   draft: 10
#   drama: 10
#   drank: 10
#   dream: 10
#   dress: 8
#   drill: 10
#   drink: 10
#   drive: 10
#   drove: 10
#   dying: 10
#   eager: 10
#   early: 10
#   earth: 10
#   eight: 10
#   elite: 10
#   empty: 10
#   enemy: 10
#   enjoy: 10
#   enter: 10
#   entry: 10
#   equal: 10
#   error: 10
#   event: 10
#   every: 10
#   exact: 10
#   exist: 10
#   extra: 10
#   faith: 10
#   false: 10
#   fault: 10
#   fiber: 10
#   field: 10
#   fifth: 10
#   fifty: 10
#   fight: 9
#   final: 10
#   first: 10
#   fixed: 10
#   flash: 10
#   fleet: 10
#   floor: 10
#   fluid: 10
#   focus: 10
#   force: 10
#   forth: 10
#   forty: 10
#   forum: 10
#   found: 10
#   frame: 10
#   frank: 10
#   fraud: 10
#   fresh: 10
#   front: 10
#   fruit: 10
#   fully: 10
#   funny: 10
#   giant: 10
#   given: 10
#   glass: 10
#   globe: 10
#   going: 10
#   grace: 10
#   grade: 10
#   grand: 10
#   grant: 10
#   grass: 10
#   grave: 10
#   great: 10
#   green: 10
#   gross: 10
#   group: 10
#   grown: 10
#   guard: 10
#   guess: 10
#   guest: 10
#   guide: 9
#   happy: 10
#   harry: 10
#   heart: 10
#   heavy: 10
#   henry: 10
#   horse: 10
#   hotel: 10
#   house: 10
#   human: 10
#   ideal: 10
#   image: 10
#   index: 10
#   inner: 10
#   input: 10
#   issue: 10
#   japan: 9
#   jimmy: 8
#   joint: 10
#   jones: 9
#   judge: 10
#   known: 10
#   label: 10
#   large: 10
#   laser: 8
#   later: 10
#   laugh: 10
#   layer: 10
#   learn: 10
#   lease: 10
#   least: 10
#   leave: 10
#   legal: 10
#   level: 10
#   lewis: 10
#   light: 10
#   limit: 10
#   links: 9
#   lives: 10
#   local: 10
#   loose: 9
#   lower: 10
#   lucky: 10
#   lunch: 10
#   lying: 10
#   magic: 10
#   major: 10
#   maker: 10
#   march: 10
#   maria: 10
#   match: 10
#   maybe: 10
#   mayor: 10
#   meant: 10
#   media: 10
#   metal: 10
#   might: 10
#   minor: 10
#   minus: 10
#   mixed: 10
#   model: 10
#   money: 10
#   month: 10
#   moral: 10
#   motor: 10
#   mount: 10
#   mouse: 10
#   mouth: 10
#   moved: 10
#   movie: 10
#   music: 5
#   needs: 10
#   never: 10
#   newly: 10
#   night: 10
#   noise: 10
#   north: 10
#   noted: 10
#   novel: 10
#   nurse: 7
#   ocean: 9
#   offer: 10
#   often: 10
#   order: 10
#   other: 10
#   ought: 9
#   paint: 10
#   panel: 10
#   paper: 10
#   party: 10
#   peace: 10
#   peter: 10
#   phase: 10
#   phone: 10
#   photo: 10
#   piano: 9
#   piece: 10
#   pilot: 10
#   pitch: 10
#   place: 10
#   plain: 10
#   plane: 10
#   plant: 10
#   plate: 10
#   point: 10
#   pound: 10
#   power: 10
#   press: 10
#   price: 10
#   pride: 10
#   prime: 10
#   print: 10
#   prior: 10
#   prize: 10
#   proof: 10
#   proud: 10
#   prove: 10
#   queen: 10
#   quick: 10
#   quiet: 9
#   quite: 10
#   radio: 10
#   raise: 10
#   range: 10
#   rapid: 10
#   ratio: 10
#   reach: 10
#   ready: 10
#   realm: 10
#   rebel: 10
#   refer: 10
#   relax: 10
#   repay: 10
#   reply: 10
#   right: 10
#   rigid: 10
#   rival: 10
#   river: 10
#   roman: 10
#   rough: 10
#   round: 10
#   route: 10
#   royal: 10
#   rural: 10
#   scale: 10
#   scene: 10
#   scope: 10
#   score: 10
#   sense: 10
#   serve: 10
#   seven: 10
#   shall: 10
#   shape: 10
#   share: 10
#   sharp: 10
#   sheet: 10
#   shelf: 10
#   shell: 10
#   shift: 10
#   shine: 10
#   shirt: 10
#   shock: 10
#   shoot: 10
#   short: 10
#   shown: 10
#   sides: 10
#   sight: 10
#   silly: 10
#   since: 10
#   sixth: 10
#   sixty: 10
#   sized: 10
#   skill: 10
#   sleep: 10
#   slide: 10
#   small: 10
#   smart: 10
#   smile: 10
#   smith: 10
#   smoke: 10
#   space: 10
#   spare: 10
#   speak: 10
#   speed: 10
#   spend: 10
#   spent: 10
#   split: 10
#   spoke: 10
#   sport: 10
#   staff: 10
#   stage: 10
#   stake: 10
#   stand: 10
#   start: 10
#   state: 10
#   steam: 10
#   steel: 10
#   steep: 10
#   steer: 9
#   stick: 10
#   still: 10
#   stock: 10
#   stone: 10
#   stood: 10
#   store: 10
#   storm: 10
#   story: 10
#   strip: 10
#   stuck: 10
#   study: 10
#   stuff: 10
#   style: 10
#   sugar: 10
#   suite: 10
#   super: 10
#   sweet: 10
#   swift: 10
#   swing: 10
#   swiss: 10
#   table: 10
#   taken: 10
#   taste: 10
#   taxes: 10
#   teach: 10
#   terry: 10
#   texas: 10
#   thank: 10
#   theft: 10
#   their: 10
#   these: 10
#   thick: 10
#   thing: 10
#   think: 10
#   third: 10
#   those: 10
#   three: 10
#   threw: 10
#   throw: 10
#   thumb: 10
#   tiger: 10
#   tight: 10
#   tower: 10
#   track: 10
#   trade: 10
#   train: 10
#   treat: 10
#   trend: 10
#   trial: 10
#   tribe: 10
#   trick: 10
#   tried: 9
#   tries: 10
#   truck: 10
#   truly: 10
#   trunk: 10
#   trust: 10
#   truth: 10
#   twice: 10
#   under: 10
#   undue: 10
#   union: 10
#   unity: 10
#   until: 10
#   upper: 10
#   upset: 10
#   urban: 10
#   usage: 10
#   usual: 6
#   valid: 10
#   value: 10
#   video: 9
#   virus: 10
#   visit: 10
#   vital: 8
#   vocal: 10
#   voice: 10
#   waste: 10
#   watch: 10
#   water: 10
#   wheel: 10
#   where: 10
#   which: 10
#   while: 10
#   white: 10
#   whole: 10
#   whose: 10
#   woman: 10
#   women: 10
#   world: 10
#   worry: 10
#   worse: 10
#   worst: 7
#   worth: 10
#   would: 10
#   write: 10
#   wrong: 10
#   wrote: 10
#   young: 10
#   youth: 10
